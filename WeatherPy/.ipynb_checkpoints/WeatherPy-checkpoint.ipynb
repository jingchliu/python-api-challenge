# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
sets=[]
for i in range(0,len(cities),50):
    set=(cities[i:i+50])
    sets.append(set)

# %%
name=[]
cloudiness=[]
country=[]
date=[]
humidity=[]
lat=[]
lng=[]
max_temp=[]
wind_speed=[]
print("Beginning Data Retrieval")
print("-"*30)
for city in sets:
    for city_name in city:
        try:
            query_url = url + "appid=" + weather_api_key + "&q=" + city_name
            response = requests.get(query_url).json()
            cloudiness.append(response["clouds"]["all"])
            humidity.append(response["main"]["humidity"])
            country.append(response["sys"]["country"])
            date.append(response["dt"])
            lat.append(response["coord"]["lat"])
            lng.append(response["coord"]["lon"])
            max_temp.append(response["main"]["temp_max"])
            wind_speed.append(response["wind"]["speed"])
            name.append(response["name"])
            print(f"Processing Record {city.index(city_name)+1} of set {sets.index(city)+1}| {city_name}")
        except:
            print("City not found. Skipping...")
            pass
print("-"*30)
print("Data Retrieval Complete")
print("-"*30)
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of set 1| port alfred
# Processing Record 2 of set 1| albany
# Processing Record 3 of set 1| ushuaia
# Processing Record 4 of set 1| chokurdakh
# Processing Record 5 of set 1| sao joao da barra
# Processing Record 6 of set 1| mataura
# City not found. Skipping...
# Processing Record 8 of set 1| luba
# Processing Record 9 of set 1| quatre cocos
# Processing Record 10 of set 1| yellowknife
# Processing Record 11 of set 1| tartus
# Processing Record 12 of set 1| jamestown
# Processing Record 13 of set 1| longyearbyen
# Processing Record 14 of set 1| soria
# Processing Record 15 of set 1| thunder bay
# Processing Record 16 of set 1| provideniya
# Processing Record 17 of set 1| barrow
# Processing Record 18 of set 1| rio branco
# Processing Record 19 of set 1| mafinga
# Processing Record 20 of set 1| faanui
# Processing Record 21 of set 1| ponta do sol
# Processing Record 22 of set 1| rikitea
# Processing Record 23 of set 1| atar
# Processing Record 24 of set 1| bluff
# Processing Record 25 of set 1| cape town
# Processing Record 26 of set 1| nisia floresta
# Processing Record 27 of set 1| mao
# Processing Record 28 of set 1| kidal
# Processing Record 29 of set 1| puerto ayora
# Processing Record 30 of set 1| punta arenas
# Processing Record 31 of set 1| bethel
# Processing Record 32 of set 1| saraland
# Processing Record 33 of set 1| victoria
# Processing Record 34 of set 1| broken hill
# Processing Record 35 of set 1| hilo
# Processing Record 36 of set 1| tuatapere
# Processing Record 37 of set 1| torbay
# Processing Record 38 of set 1| labuhan
# Processing Record 39 of set 1| fortuna
# Processing Record 40 of set 1| atuona
# Processing Record 41 of set 1| taoudenni
# Processing Record 42 of set 1| pangnirtung
# Processing Record 43 of set 1| korla
# Processing Record 44 of set 1| meadow lake
# Processing Record 45 of set 1| shadrinsk
# Processing Record 46 of set 1| lavrentiya
# Processing Record 47 of set 1| busselton
# Processing Record 48 of set 1| alto araguaia
# Processing Record 49 of set 1| narsaq
# Processing Record 50 of set 1| eyl
# Processing Record 1 of set 2| hobart
# Processing Record 2 of set 2| clyde river
# Processing Record 3 of set 2| bouloupari
# Processing Record 4 of set 2| lompoc
# Processing Record 5 of set 2| valsad
# Processing Record 6 of set 2| cherskiy
# Processing Record 7 of set 2| bairiki
# Processing Record 8 of set 2| alofi
# Processing Record 9 of set 2| vardo
# Processing Record 10 of set 2| jawa
# Processing Record 11 of set 2| norwich
# Processing Record 12 of set 2| luganville
# Processing Record 13 of set 2| tiarei
# Processing Record 14 of set 2| cabo san lucas
# City not found. Skipping...
# Processing Record 16 of set 2| esperance
# Processing Record 17 of set 2| cockburn town
# Processing Record 18 of set 2| dunedin
# Processing Record 19 of set 2| hermanus
# Processing Record 20 of set 2| new norfolk
# Processing Record 21 of set 2| saint-philippe
# Processing Record 22 of set 2| carnarvon
# Processing Record 23 of set 2| kavieng
# Processing Record 24 of set 2| panama city
# Processing Record 25 of set 2| vaini
# Processing Record 26 of set 2| bredasdorp
# Processing Record 27 of set 2| northam
# Processing Record 28 of set 2| cayenne
# Processing Record 29 of set 2| cidreira
# Processing Record 30 of set 2| quelimane
# Processing Record 31 of set 2| aykhal
# Processing Record 32 of set 2| mumford
# City not found. Skipping...
# Processing Record 34 of set 2| bathsheba
# Processing Record 35 of set 2| tarakan
# City not found. Skipping...
# Processing Record 37 of set 2| tasiilaq
# Processing Record 38 of set 2| port elizabeth
# Processing Record 39 of set 2| minudasht
# Processing Record 40 of set 2| banepa
# Processing Record 41 of set 2| kapaa
# Processing Record 42 of set 2| bitung
# Processing Record 43 of set 2| qaanaaq
# Processing Record 44 of set 2| puerto narino
# City not found. Skipping...
# Processing Record 46 of set 2| coihaique
# Processing Record 47 of set 2| caravelas
# Processing Record 48 of set 2| huambo
# Processing Record 49 of set 2| hofn
# Processing Record 50 of set 2| ribeira grande
# Processing Record 1 of set 3| thompson
# Processing Record 2 of set 3| kahului
# City not found. Skipping...
# Processing Record 4 of set 3| talnakh
# Processing Record 5 of set 3| saint george
# Processing Record 6 of set 3| upernavik
# Processing Record 7 of set 3| dikson
# Processing Record 8 of set 3| margate
# Processing Record 9 of set 3| vao
# Processing Record 10 of set 3| hasaki
# Processing Record 11 of set 3| sioux lookout
# Processing Record 12 of set 3| ormara
# Processing Record 13 of set 3| aklavik
# Processing Record 14 of set 3| nanortalik
# Processing Record 15 of set 3| iqaluit
# Processing Record 16 of set 3| wanganui
# Processing Record 17 of set 3| nanning
# City not found. Skipping...
# Processing Record 19 of set 3| okhotsk
# City not found. Skipping...
# Processing Record 21 of set 3| slobodskoy
# Processing Record 22 of set 3| verkhnevilyuysk
# Processing Record 23 of set 3| concordia
# City not found. Skipping...
# Processing Record 25 of set 3| camopi
# Processing Record 26 of set 3| noumea
# Processing Record 27 of set 3| axim
# Processing Record 28 of set 3| aksay
# Processing Record 29 of set 3| nakhon sawan
# Processing Record 30 of set 3| kaitangata
# Processing Record 31 of set 3| mtinko
# Processing Record 32 of set 3| tuktoyaktuk
# Processing Record 33 of set 3| isangel
# Processing Record 34 of set 3| isla mujeres
# Processing Record 35 of set 3| musoma
# Processing Record 36 of set 3| billings
# Processing Record 37 of set 3| balkanabat
# Processing Record 38 of set 3| pozo colorado
# Processing Record 39 of set 3| jalu
# Processing Record 40 of set 3| san cristobal
# Processing Record 41 of set 3| kavaratti
# Processing Record 42 of set 3| bambous virieux
# City not found. Skipping...
# Processing Record 44 of set 3| kawalu
# Processing Record 45 of set 3| french harbor
# Processing Record 46 of set 3| lorengau
# Processing Record 47 of set 3| sao gabriel da cachoeira
# Processing Record 48 of set 3| vila franca do campo
# Processing Record 49 of set 3| comodoro rivadavia
# Processing Record 50 of set 3| igarka
# Processing Record 1 of set 4| tereze
# City not found. Skipping...
# Processing Record 3 of set 4| channel-port aux basques
# Processing Record 4 of set 4| srednekolymsk
# Processing Record 5 of set 4| saskylakh
# Processing Record 6 of set 4| aguimes
# Processing Record 7 of set 4| elko
# Processing Record 8 of set 4| zhigansk
# Processing Record 9 of set 4| butaritari
# Processing Record 10 of set 4| gobabis
# Processing Record 11 of set 4| waipawa
# Processing Record 12 of set 4| san patricio
# Processing Record 13 of set 4| gladstone
# Processing Record 14 of set 4| lebu
# Processing Record 15 of set 4| hithadhoo
# Processing Record 16 of set 4| alice springs
# Processing Record 17 of set 4| geraldton
# Processing Record 18 of set 4| klyuchi
# Processing Record 19 of set 4| salalah
# Processing Record 20 of set 4| port-gentil
# Processing Record 21 of set 4| ancud
# Processing Record 22 of set 4| arraial do cabo
# Processing Record 23 of set 4| lewistown
# City not found. Skipping...
# Processing Record 25 of set 4| bandarbeyla
# Processing Record 26 of set 4| sorland
# Processing Record 27 of set 4| durango
# Processing Record 28 of set 4| camana
# Processing Record 29 of set 4| big bend
# Processing Record 30 of set 4| sao filipe
# Processing Record 31 of set 4| luau
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of set 4| hami
# Processing Record 35 of set 4| south lake tahoe
# Processing Record 36 of set 4| mandalgovi
# Processing Record 37 of set 4| talara
# Processing Record 38 of set 4| minbu
# Processing Record 39 of set 4| fairbanks
# Processing Record 40 of set 4| avarua
# Processing Record 41 of set 4| ugoofaaru
# Processing Record 42 of set 4| sembakung
# City not found. Skipping...
# Processing Record 44 of set 4| te anau
# Processing Record 45 of set 4| nikolskoye
# Processing Record 46 of set 4| klaksvik
# City not found. Skipping...
# Processing Record 48 of set 4| morden
# Processing Record 49 of set 4| zaysan
# Processing Record 50 of set 4| beira
# Processing Record 1 of set 5| sandy bay
# Processing Record 2 of set 5| airai
# Processing Record 3 of set 5| camacha
# Processing Record 4 of set 5| muscat
# Processing Record 5 of set 5| rosarito
# Processing Record 6 of set 5| sur
# Processing Record 7 of set 5| tonala
# Processing Record 8 of set 5| nueva germania
# Processing Record 9 of set 5| bondo
# Processing Record 10 of set 5| kaduqli
# Processing Record 11 of set 5| masvingo
# Processing Record 12 of set 5| maceio
# Processing Record 13 of set 5| okakarara
# Processing Record 14 of set 5| kanniyakumari
# Processing Record 15 of set 5| mangrol
# Processing Record 16 of set 5| usinsk
# Processing Record 17 of set 5| irati
# Processing Record 18 of set 5| castro
# Processing Record 19 of set 5| haines junction
# Processing Record 20 of set 5| derzhavinsk
# Processing Record 21 of set 5| trinidad
# City not found. Skipping...
# Processing Record 23 of set 5| dingalan
# Processing Record 24 of set 5| hondo
# City not found. Skipping...
# Processing Record 26 of set 5| luderitz
# Processing Record 27 of set 5| shelburne
# Processing Record 28 of set 5| san jose
# Processing Record 29 of set 5| mnogovershinnyy
# Processing Record 30 of set 5| kaeo
# Processing Record 31 of set 5| tecoanapa
# Processing Record 32 of set 5| steamboat springs
# Processing Record 33 of set 5| santa cruz
# Processing Record 34 of set 5| siniscola
# Processing Record 35 of set 5| manokwari
# Processing Record 36 of set 5| tandil
# Processing Record 37 of set 5| yulara
# Processing Record 38 of set 5| saldanha
# Processing Record 39 of set 5| miri
# Processing Record 40 of set 5| dauphin
# Processing Record 41 of set 5| nador
# Processing Record 42 of set 5| dingle
# Processing Record 43 of set 5| tiznit
# Processing Record 44 of set 5| cap malheureux
# Processing Record 45 of set 5| laela
# Processing Record 46 of set 5| rio grande
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of set 5| kandrian
# Processing Record 50 of set 5| eirunepe
# Processing Record 1 of set 6| codrington
# Processing Record 2 of set 6| kailua
# Processing Record 3 of set 6| berlevag
# Processing Record 4 of set 6| faya
# Processing Record 5 of set 6| voznesenye
# City not found. Skipping...
# Processing Record 7 of set 6| pevek
# Processing Record 8 of set 6| ranau
# Processing Record 9 of set 6| east london
# Processing Record 10 of set 6| avera
# Processing Record 11 of set 6| livani
# Processing Record 12 of set 6| hinatuan
# Processing Record 13 of set 6| karratha
# Processing Record 14 of set 6| araouane
# Processing Record 15 of set 6| muravlenko
# Processing Record 16 of set 6| aranos
# Processing Record 17 of set 6| half moon bay
# Processing Record 18 of set 6| motygino
# Processing Record 19 of set 6| aswan
# City not found. Skipping...
# Processing Record 21 of set 6| miami
# Processing Record 22 of set 6| skibbereen
# Processing Record 23 of set 6| coari
# Processing Record 24 of set 6| bengkulu
# Processing Record 25 of set 6| mar del plata
# Processing Record 26 of set 6| kralendijk
# Processing Record 27 of set 6| torres
# Processing Record 28 of set 6| patos de minas
# Processing Record 29 of set 6| portsmouth
# Processing Record 30 of set 6| tabou
# Processing Record 31 of set 6| miranda
# Processing Record 32 of set 6| libreville
# Processing Record 33 of set 6| shingu
# Processing Record 34 of set 6| hualmay
# Processing Record 35 of set 6| dorado
# Processing Record 36 of set 6| osoyoos
# Processing Record 37 of set 6| norman wells
# Processing Record 38 of set 6| khatanga
# Processing Record 39 of set 6| asyut
# Processing Record 40 of set 6| amot
# Processing Record 41 of set 6| krasnoselskiy
# Processing Record 42 of set 6| hambantota
# Processing Record 43 of set 6| gondanglegi
# Processing Record 44 of set 6| lithakia
# Processing Record 45 of set 6| naze
# Processing Record 46 of set 6| mahebourg
# Processing Record 47 of set 6| duku
# Processing Record 48 of set 6| tinskoy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of set 7| preobrazheniye
# Processing Record 2 of set 7| buzuluk
# Processing Record 3 of set 7| parintins
# Processing Record 4 of set 7| tiksi
# Processing Record 5 of set 7| touros
# Processing Record 6 of set 7| bilibino
# Processing Record 7 of set 7| brae
# Processing Record 8 of set 7| puerto escondido
# Processing Record 9 of set 7| iracoubo
# Processing Record 10 of set 7| pacific grove
# Processing Record 11 of set 7| katav-ivanovsk
# Processing Record 12 of set 7| morales
# Processing Record 13 of set 7| padang
# Processing Record 14 of set 7| sitrah
# Processing Record 15 of set 7| sibolga
# Processing Record 16 of set 7| portland
# Processing Record 17 of set 7| rawson
# Processing Record 18 of set 7| soyo
# Processing Record 19 of set 7| san blas
# Processing Record 20 of set 7| guerrero negro
# Processing Record 21 of set 7| vila velha
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of set 7| beringovskiy
# Processing Record 26 of set 7| georgetown
# Processing Record 27 of set 7| port hardy
# City not found. Skipping...
# Processing Record 29 of set 7| shakhtinsk
# Processing Record 30 of set 7| dali
# Processing Record 31 of set 7| homer
# City not found. Skipping...
# Processing Record 33 of set 7| omboue
# Processing Record 34 of set 7| dudinka
# Processing Record 35 of set 7| la palma
# Processing Record 36 of set 7| moranbah
# Processing Record 37 of set 7| odienne
# Processing Record 38 of set 7| muyezerskiy
# City not found. Skipping...
# Processing Record 40 of set 7| mount gambier
# Processing Record 41 of set 7| kununurra
# Processing Record 42 of set 7| qaqortoq
# Processing Record 43 of set 7| ewa beach
# Processing Record 44 of set 7| nantucket
# Processing Record 45 of set 7| atlantic city
# Processing Record 46 of set 7| teknaf
# Processing Record 47 of set 7| scarborough
# Processing Record 48 of set 7| kargil
# Processing Record 49 of set 7| puteyets
# Processing Record 50 of set 7| wasilla
# Processing Record 1 of set 8| bonavista
# Processing Record 2 of set 8| durusu
# Processing Record 3 of set 8| port-cartier
# Processing Record 4 of set 8| pakruojis
# Processing Record 5 of set 8| genoa
# Processing Record 6 of set 8| mitu
# Processing Record 7 of set 8| constitucion
# Processing Record 8 of set 8| walvis bay
# Processing Record 9 of set 8| carmen
# Processing Record 10 of set 8| xuanhua
# Processing Record 11 of set 8| kharan
# Processing Record 12 of set 8| ruteng
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of set 8| yumen
# Processing Record 16 of set 8| palauig
# Processing Record 17 of set 8| russell
# Processing Record 18 of set 8| pisco
# Processing Record 19 of set 8| marawi
# Processing Record 20 of set 8| marzuq
# Processing Record 21 of set 8| palamos
# Processing Record 22 of set 8| port lincoln
# Processing Record 23 of set 8| san rafael
# Processing Record 24 of set 8| omsukchan
# Processing Record 25 of set 8| grand gaube
# Processing Record 26 of set 8| berezovyy
# City not found. Skipping...
# Processing Record 28 of set 8| mogadishu
# Processing Record 29 of set 8| antalaha
# Processing Record 30 of set 8| ontario
# Processing Record 31 of set 8| tual
# City not found. Skipping...
# Processing Record 33 of set 8| verkhoyansk
# Processing Record 34 of set 8| cacule
# Processing Record 35 of set 8| frontignan
# Processing Record 36 of set 8| hernani
# Processing Record 37 of set 8| neiafu
# Processing Record 38 of set 8| olafsvik
# Processing Record 39 of set 8| codajas
# Processing Record 40 of set 8| veliki preslav
# Processing Record 41 of set 8| rabo de peixe
# Processing Record 42 of set 8| kudahuvadhoo
# City not found. Skipping...
# Processing Record 44 of set 8| katobu
# Processing Record 45 of set 8| leh
# Processing Record 46 of set 8| chuy
# Processing Record 47 of set 8| tsaratanana
# Processing Record 48 of set 8| tevaitoa
# Processing Record 49 of set 8| severo-kurilsk
# Processing Record 50 of set 8| hirara
# Processing Record 1 of set 9| shimoda
# Processing Record 2 of set 9| papayal
# Processing Record 3 of set 9| itarema
# Processing Record 4 of set 9| toppenish
# Processing Record 5 of set 9| paamiut
# City not found. Skipping...
# Processing Record 7 of set 9| solnechnyy
# Processing Record 8 of set 9| katsuura
# Processing Record 9 of set 9| joshimath
# Processing Record 10 of set 9| katra
# Processing Record 11 of set 9| xapuri
# Processing Record 12 of set 9| yar-sale
# Processing Record 13 of set 9| porosozero
# Processing Record 14 of set 9| otavi
# Processing Record 15 of set 9| kasempa
# City not found. Skipping...
# Processing Record 17 of set 9| mansa
# Processing Record 18 of set 9| shama
# Processing Record 19 of set 9| vostok
# Processing Record 20 of set 9| chiang klang
# Processing Record 21 of set 9| mookane
# Processing Record 22 of set 9| kamen-na-obi
# Processing Record 23 of set 9| stokmarknes
# Processing Record 24 of set 9| viedma
# Processing Record 25 of set 9| bardiyah
# Processing Record 26 of set 9| canutama
# Processing Record 27 of set 9| shache
# Processing Record 28 of set 9| stolin
# Processing Record 29 of set 9| glendive
# Processing Record 30 of set 9| gimli
# Processing Record 31 of set 9| bintulu
# Processing Record 32 of set 9| mishelevka
# Processing Record 33 of set 9| roebourne
# Processing Record 34 of set 9| greymouth
# Processing Record 35 of set 9| shenjiamen
# Processing Record 36 of set 9| souillac
# Processing Record 37 of set 9| tigre
# City not found. Skipping...
# Processing Record 39 of set 9| lazaro cardenas
# Processing Record 40 of set 9| izhma
# Processing Record 41 of set 9| pacocha
# Processing Record 42 of set 9| haskovo
# Processing Record 43 of set 9| takoradi
# Processing Record 44 of set 9| umm kaddadah
# Processing Record 45 of set 9| gamba
# Processing Record 46 of set 9| college
# City not found. Skipping...
# Processing Record 48 of set 9| concarneau
# Processing Record 49 of set 9| yeppoon
# Processing Record 50 of set 9| tura
# Processing Record 1 of set 10| mantua
# Processing Record 2 of set 10| arki
# Processing Record 3 of set 10| anadyr
# Processing Record 4 of set 10| los llanos de aridane
# Processing Record 5 of set 10| beyneu
# Processing Record 6 of set 10| kyshtovka
# Processing Record 7 of set 10| east millcreek
# Processing Record 8 of set 10| huilong
# Processing Record 9 of set 10| nishihara
# Processing Record 10 of set 10| kyzyl-suu
# Processing Record 11 of set 10| visnes
# Processing Record 12 of set 10| doka
# City not found. Skipping...
# Processing Record 14 of set 10| inhambane
# City not found. Skipping...
# Processing Record 16 of set 10| susanville
# Processing Record 17 of set 10| ugento
# Processing Record 18 of set 10| pundaguitan
# Processing Record 19 of set 10| kuytun
# Processing Record 20 of set 10| svetlogorsk
# Processing Record 21 of set 10| warrnambool
# Processing Record 22 of set 10| tukan
# Processing Record 23 of set 10| banamba
# Processing Record 24 of set 10| tabas
# Processing Record 25 of set 10| lampa
# Processing Record 26 of set 10| la rioja
# City not found. Skipping...
# Processing Record 28 of set 10| ust-kulom
# Processing Record 29 of set 10| coahuayana
# Processing Record 30 of set 10| kodiak
# Processing Record 31 of set 10| the valley
# Processing Record 32 of set 10| abu dhabi
# Processing Record 33 of set 10| marrakesh
# Processing Record 34 of set 10| sikandra
# Processing Record 35 of set 10| bowen
# Processing Record 36 of set 10| vuktyl
# Processing Record 37 of set 10| coos bay
# Processing Record 38 of set 10| sola
# Processing Record 39 of set 10| rio pardo de minas
# Processing Record 40 of set 10| trairi
# Processing Record 41 of set 10| ottawa
# Processing Record 42 of set 10| olga
# Processing Record 43 of set 10| hovd
# Processing Record 44 of set 10| aksarka
# Processing Record 45 of set 10| celestun
# Processing Record 46 of set 10| ayan
# Processing Record 47 of set 10| nizhniy odes
# Processing Record 48 of set 10| peniche
# City not found. Skipping...
# Processing Record 50 of set 10| buala
# Processing Record 1 of set 11| barabai
# Processing Record 2 of set 11| plouzane
# Processing Record 3 of set 11| san pedro
# Processing Record 4 of set 11| urengoy
# Processing Record 5 of set 11| leningradskiy
# Processing Record 6 of set 11| acari
# Processing Record 7 of set 11| lakselv
# Processing Record 8 of set 11| baykit
# City not found. Skipping...
# Processing Record 10 of set 11| invermere
# Processing Record 11 of set 11| pitimbu
# Processing Record 12 of set 11| provo
# Processing Record 13 of set 11| hervey bay
# Processing Record 14 of set 11| sitka
# Processing Record 15 of set 11| lanxi
# Processing Record 16 of set 11| pandan
# Processing Record 17 of set 11| savannah bight
# Processing Record 18 of set 11| praia da vitoria
# Processing Record 19 of set 11| sobolevo
# Processing Record 20 of set 11| black river
# Processing Record 21 of set 11| ostrovnoy
# Processing Record 22 of set 11| kimbe
# Processing Record 23 of set 11| boyolangu
# Processing Record 24 of set 11| ucluelet
# City not found. Skipping...
# Processing Record 26 of set 11| port macquarie
# Processing Record 27 of set 11| kalispell
# Processing Record 28 of set 11| llanes
# Processing Record 29 of set 11| nemuro
# Processing Record 30 of set 11| magole
# Processing Record 31 of set 11| wukari
# Processing Record 32 of set 11| novyy urengoy
# Processing Record 33 of set 11| preeceville
# Processing Record 34 of set 11| minab
# Processing Record 35 of set 11| quzhou
# Processing Record 36 of set 11| tocopilla
# Processing Record 37 of set 11| evensk
# Processing Record 38 of set 11| adrar
# Processing Record 39 of set 11| rio gallegos
# Processing Record 40 of set 11| sinop
# Processing Record 41 of set 11| fort nelson
# Processing Record 42 of set 11| santander
# Processing Record 43 of set 11| inuvik
# Processing Record 44 of set 11| birjand
# Processing Record 45 of set 11| werda
# Processing Record 46 of set 11| zhuhai
# Processing Record 47 of set 11| stromness
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of set 11| morgan city
# Processing Record 1 of set 12| tilichiki
# Processing Record 2 of set 12| turayf
# Processing Record 3 of set 12| nazca
# Processing Record 4 of set 12| antofagasta
# Processing Record 5 of set 12| san ramon
# Processing Record 6 of set 12| salinopolis
# Processing Record 7 of set 12| batemans bay
# Processing Record 8 of set 12| mocuba
# Processing Record 9 of set 12| sinnamary
# City not found. Skipping...
# Processing Record 11 of set 12| lagoa
# Processing Record 12 of set 12| spirit river
# Processing Record 13 of set 12| aljezur
# Processing Record 14 of set 12| saint anthony
# Processing Record 15 of set 12| yerbogachen
# Processing Record 16 of set 12| aksu
# Processing Record 17 of set 12| port blair
# Processing Record 18 of set 12| jibuti
# Processing Record 19 of set 12| manjacaze
# Processing Record 20 of set 12| grindavik
# City not found. Skipping...
# Processing Record 22 of set 12| edd
# Processing Record 23 of set 12| aldama
# Processing Record 24 of set 12| ahipara
# Processing Record 25 of set 12| bosaso
# Processing Record 26 of set 12| beisfjord
# Processing Record 27 of set 12| bereda
# Processing Record 28 of set 12| conneaut
# City not found. Skipping...
# Processing Record 30 of set 12| husavik
# Processing Record 31 of set 12| hammerfest
# Processing Record 32 of set 12| namatanai
# Processing Record 33 of set 12| kalinovskaya
# Processing Record 34 of set 12| amahai
# Processing Record 35 of set 12| gurmatkal
# Processing Record 36 of set 12| sabancuy
# Processing Record 37 of set 12| jasper
# Processing Record 38 of set 12| koslan
# Processing Record 39 of set 12| shimanovsk
# Processing Record 40 of set 12| quiroga
# Processing Record 41 of set 12| boysun
# Processing Record 42 of set 12| santa maria
# Processing Record 43 of set 12| fethiye
# Processing Record 44 of set 12| nouadhibou
# Processing Record 45 of set 12| shu
# Processing Record 46 of set 12| itoman
# Processing Record 47 of set 12| lokosovo
# Processing Record 48 of set 12| pastavy
# Processing Record 49 of set 12| presidencia roque saenz pena
# Processing Record 50 of set 12| seoul
# City not found. Skipping...
# Processing Record 2 of set 13| lasa
# Processing Record 3 of set 13| changping
# Processing Record 4 of set 13| kokoda
# Processing Record 5 of set 13| kassala
# Processing Record 6 of set 13| novokizhinginsk
# Processing Record 7 of set 13| marsaxlokk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 of set 13| saint-pierre
# Processing Record 11 of set 13| carauari
# Processing Record 12 of set 13| vanimo
# Processing Record 13 of set 13| kuybyshevskiy zaton
# Processing Record 14 of set 13| laguna
# City not found. Skipping...
# Processing Record 16 of set 13| ilulissat
# Processing Record 17 of set 13| great yarmouth
# Processing Record 18 of set 13| thinadhoo
# Processing Record 19 of set 13| tautira
# Processing Record 20 of set 13| dapaong
# Processing Record 21 of set 13| lubumbashi
# Processing Record 22 of set 13| bubaque
# Processing Record 23 of set 13| kuryk
# Processing Record 24 of set 13| naryan-mar
# Processing Record 25 of set 13| okato
# Processing Record 26 of set 13| goderich
# City not found. Skipping...
# Processing Record 28 of set 13| kampot
# Processing Record 29 of set 13| indiana
# Processing Record 30 of set 13| kalangala
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data_df=pd.DataFrame(
{
    "City":name,
    "Cloudiness":cloudiness,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lat,
    "Lng":lng,
    "Max Temp":max_temp,
    "Wind Speed":wind_speed
}
)
data_df.head()
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        Port Alfred           0      ZA  1578787347        94 -33.59   26.89
# 1             Albany          90      US  1578787335        82  42.60  -73.97
# 2            Ushuaia          75      AR  1578787202        76 -54.80  -68.30
# 3         Chokurdakh          19      RU  1578787353        99  70.63  147.92
# 4  Sao Joao da Barra         100      BR  1578787524        80 -21.64  -41.05
#
#    Max Temp  Wind Speed
# 0    293.71        4.92
# 1    291.15        2.10
# 2    284.15        5.70
# 3    238.83        1.35
# 4    299.26        5.60

# %%
data_df.count()
# Out:
# City          575
# Cloudiness    575
# Country       575
# Date          575
# Humidity      575
# Lat           575
# Lng           575
# Max Temp      575
# Wind Speed    575
# dtype: int64

# %%
data_df.to_csv("result/Weather result.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lat,max_temp,marker="o",facecolors="slategrey",edgecolors="black",s=30)
plt.title("City Latitude vs. Max Temperature(01/11/2020)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("result/weather1.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat,humidity,marker="o",facecolors="slategrey",edgecolors="black",s=30)
plt.title("City Latitude vs. Humidity (01/11/2020)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("result/weather2.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat,cloudiness,marker="o",facecolors="slategrey",edgecolors="black",s=30)
plt.title("City Latitude vs. Cloudiness (01/11/2020)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("result/weather3.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat,wind_speed,marker="o",facecolors="slategrey",edgecolors="black",s=30)
plt.title("City Latitude vs. Wind Speed (01/11/2020)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("result/weather4.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_regression(x,y,loc_x,loc_y):
    slope,intercept,rvalue,pvalue,stderr=linregress(x,y)
    regression_values=x*slope+intercept
    line_eq=f"y={round(slope,2)}x+{round(intercept,2)}"
    print(f"The r-squared is: {rvalue}")
    plt.plot(x,regression_values,'r-')
    plt.annotate(line_eq,(loc_x,loc_y),fontsize=15,color="red")

# %%
# Create Northern and Southern Hemisphere DataFrames
north_df=data_df.loc[data_df["Lat"]>0]
south_df=data_df.loc[data_df["Lat"]<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(north_df["Lat"],north_df["Max Temp"],marker="o",facecolors="slategrey",edgecolors="black",s=30)
plt.title("Northern Hemisphere - City Latitude vs. Max Temperature(01/11/2020)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
linear_regression(north_df["Lat"],north_df["Max Temp"],10,250)

plt.savefig("result/weather5.png")
# Out:
# The r-squared is: -0.8447673696912633

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(south_df["Lat"],south_df["Max Temp"],marker="o",facecolors="slategrey",edgecolors="black",s=30)
plt.title("Southern Hemisphere - City Latitude vs. Max Temperature(01/11/2020)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
linear_regression(south_df["Lat"],south_df["Max Temp"],-25,286)

plt.savefig("result/weather6.png")
# Out:
# The r-squared is: 0.4342353907201074

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(north_df["Lat"],north_df["Humidity"],marker="o",facecolors="slategrey",edgecolors="black",s=30)
plt.title("Northern Hemisphere - City Latitude vs. Humidity(01/11/2020)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
linear_regression(north_df["Lat"],north_df["Humidity"],40,20)

plt.savefig("result/weather7.png")
# Out:
# The r-squared is: 0.28280401721373133

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(south_df["Lat"],south_df["Humidity"],marker="o",facecolors="slategrey",edgecolors="black",s=30)
plt.title("Southern Hemisphere - City Latitude vs. Humidity(01/11/2020)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.ylim(30,200)
linear_regression(south_df["Lat"],south_df["Humidity"],-30,150)

plt.savefig("result/weather8.png")
# Out:
# The r-squared is: 0.41615757531067454

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(north_df["Lat"],north_df["Cloudiness"],marker="o",facecolors="slategrey",edgecolors="black",s=30)
plt.title("Northern Hemisphere - City Latitude vs. Cloudiness (01/11/2020)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
linear_regression(north_df["Lat"],north_df["Cloudiness"],40,20)

plt.savefig("result/weather9.png")
# Out:
# The r-squared is: 0.34532677263496214

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(south_df["Lat"],south_df["Cloudiness"],marker="o",facecolors="slategrey",edgecolors="black",s=30)
plt.title("Southern Hemisphere - City Latitude vs. Cloudiness (01/11/2020)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
linear_regression(south_df["Lat"],south_df["Cloudiness"],-30,30)

plt.savefig("result/weather10.png")
# Out:
# The r-squared is: 0.3539189778951492

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(north_df["Lat"],north_df["Wind Speed"],marker="o",facecolors="slategrey",edgecolors="black",s=30)
plt.title("Northern Hemisphere - City Latitude vs. Wind Speed (01/11/2020)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
linear_regression(north_df["Lat"],north_df["Wind Speed"],30,15)

plt.savefig("result/weather11.png")
# Out:
# The r-squared is: 0.10570104342170089

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(south_df["Lat"],south_df["Wind Speed"],marker="o",facecolors="slategrey",edgecolors="black",s=30)
plt.title("Southern Hemisphere - City Latitude vs. Wind Speed (01/11/2020)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
linear_regression(south_df["Lat"],south_df["Wind Speed"],-30,10)

plt.savefig("result/weather12.png")
# Out:
# The r-squared is: -0.30832119630839805

# %% [markdown]
# Observations:
#  - There's a strong relationship between latitue and maximum temperature: The maximum temperature declines as the latidute increases in the nothern hemisphere and vice versa for the southern hemisphere. The correlation is stronger in the nothern hemisphere as it has a higher r-squared value. Probably because there are more cities in the southern hemisphere with a higher latitude location, so we can't see as clear trend as we see in the nother hemisphere.
#  - The dataset did not exhibit a clear relationship between the latitude and cloudiness/ wind speed for both hemispheres as the data was spread out and the r-squared values are small.
#  - The data indicates that the higher latitude, the higher humidity we get. But the conclusion is not reliable since there are many other factors. Latitude is most likely a stronger factor of the max temperature for cities only.
